# %% [markdown]
# # 13. 함수적용
# ---
# - pandas에서 데이터 변형을 수행할 때, apply()함수는 강력한 도구이다.
# - 이함수를 사용하면 DataFrame 또는 Series의 각 요소에 대해 원하는 연산을 수행 할 수 있다.

# %%
import pandas as pd
df = pd.read_csv('data/customers3.csv', index_col='고객ID')
df
# Out:
#       고객명  나이 거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics         75         70        78        92
# C002  이영희  30   안양      fashion         85         92        88        85
# C003  박지성  35   울산          NaN         95        110        91        88
# C004  최민아  40   창원      Fashion         92        105        82        96
# C005  정수빈  28   구로      Fashion         82         88        94        79
# C006  윤태영  27   시흥  Electronics         88         95        85        91
# C007  한유진  31   파주          NaN         68         65        77        83
# C008  강민호  29   일산       Sports         98        125        96        90

# %%
#df['최근1년_방문빈도'] = df['최근1년_방문빈도'] + '회'
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['최근1년_방문빈도'] = df['최근1년_방문빈도'] + '회'
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)    184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\series.py:6154, in Series._arith_method(self, other, op)
#    6152 def _arith_method(self, other, op):
#    6153     self, other = self._align_for_op(other)
# -> 6154     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('int64'), dtype('<U1')) -> None

# %% [markdown]
# **데이터에 함수 적용 `apply()`**
# - DataFrame이나 Series의 각 요소에 함수를 적용할 때 사용된다.
# - 특히 열(Column) 단위나 행(row) 단위로 복잡한 연산을 적용할 때 유용하다.

# %%
def add_keyword(count):
    return str(count) + '회'

# %%
add_keyword(5)
# Out:
# '5회'

# %%
df['최근1년_방문빈도'] = df['최근1년_방문빈도'].apply(add_keyword)

df
# Out:
#       고객명  나이 거주도시        주요관심사 최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics      75회회         70        78        92
# C002  이영희  30   안양      fashion      85회회         92        88        85
# C003  박지성  35   울산          NaN      95회회        110        91        88
# C004  최민아  40   창원      Fashion      92회회        105        82        96
# C005  정수빈  28   구로      Fashion      82회회         88        94        79
# C006  윤태영  27   시흥  Electronics      88회회         95        85        91
# C007  한유진  31   파주          NaN      68회회         65        77        83
# C008  강민호  29   일산       Sports      98회회        125        96        90

# %%
# 첫번째 문자가 대문자인지 아닌지 -> 대문자가 아니면 대문자로 변환
def capitalize(interest):
    if pd.notnull(interest):
        return interest.capitalize()
    return interest

# %%
df['주요관심사'] = df['주요관심사'].apply(capitalize)

df
# Out:
#       고객명  나이 거주도시        주요관심사 최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 고객ID
# C001  박태근  35   시흥  Electronics      75회회         70        78        92
# C002  이영희  30   안양      Fashion      85회회         92        88        85
# C003  박지성  35   울산          NaN      95회회        110        91        88
# C004  최민아  40   창원      Fashion      92회회        105        82        96
# C005  정수빈  28   구로      Fashion      82회회         88        94        79
# C006  윤태영  27   시흥  Electronics      88회회         95        85        91
# C007  한유진  31   파주          NaN      68회회         65        77        83
# C008  강민호  29   일산       Sports      98회회        125        96        90

# %% [markdown]
# **`merge()`**
# - SQL의 JOIN과 유사하게 두개의 DataFrame을 특정 열을 기준으로 결합한다.

# %%
df1 = pd.DataFrame(
    {
        'CustomerID' : [1,2,3],
        'Product' : ['Laptop','Mounse','Keyboard']
    }
)

df1
# Out:
#    CustomerID   Product
# 0           1    Laptop
# 1           2    Mounse
# 2           3  Keyboard

# %%
df2 = pd.DataFrame(
    {
        'CustomerID' : [3,2,1],
        'Location' : ['USA','Canada','Korea']
    }
)
df2
# Out:
#    CustomerID Location
# 0           3      USA
# 1           2   Canada
# 2           1    Korea

# %%
df_merge = pd.merge(df1, df2, on='CustomerID')

# %%
df_merge
# Out:
#    CustomerID   Product Location
# 0           1    Laptop    Korea
# 1           2    Mounse   Canada
# 2           3  Keyboard      USA

# %% [markdown]
# **`concat()`**
# - DataFrame을 위아래또는 좌, 우로 결합할때 사용한다.
# - 행을 추가할때는 `axis=0`, 열을추가할땐는 `axis=1`을 사용한다.

# %%
df1 = pd.DataFrame(
    {
        'A' : ['A0', 'A1'],
        'B' : ['B0','B1']
    }
)
df1
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1

# %%
df2 = pd.DataFrame(
    {
        'A' : ['A2', 'A3'],
        'B' : ['B2','B3']
    }
)
df2
# Out:
#     A   B
# 0  A2  B2
# 1  A3  B3

# %%
df_concat = pd.concat([df1, df2], axis=0)
df_concat
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %% [markdown]
# **`join()`**
# - 두개의 DataFrame을 인덱스를 기준으로 결합 할 때 사용한다.

# %%
df1 = pd.DataFrame(
    {
        'A' : ['A0', 'A1'], 
    },
    index = ['K0','K1']
)
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1

# %%
df2 = pd.DataFrame(
    {
        'B' : ['B0','B1'],
    },
    index = ['K0','K1']
)
df2
# Out:
#      B
# K0  B0
# K1  B1

# %%
df_join = df1.join(df2)

df_join
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df_join = df1.join(df2)
#       3 df_join
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\frame.py:10784, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10774     if how == "cross":
#   10775         return merge(
#   10776             self,
#   10777             other,
#    (...)  10782             validate=validate,
#   10783         )
# > 10784     return merge(
#   10785         self,
#   10786         other,
#   10787         left_on=on,
#   10788         how=how,
#   10789         left_index=on is None,
#   10790         right_index=True,
#   10791         suffixes=(lsuffix, rsuffix),
#   10792         sort=sort,
#   10793         validate=validate,
#   10794     )
#   10795 else:
#   10796     if on is not None:
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)    182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)    855         use_na_proxy=True,
#     856     )
#
# File c:\ProgramData\miniforge3\envs\helloworld\Lib\site-packages\pandas\core\reshape\merge.py:2721, in _items_overlap_with_suffix(left, right, suffixes)
#    2718 lsuffix, rsuffix = suffixes
#    2720 if not lsuffix and not rsuffix:
# -> 2721     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2723 def renamer(x, suffix: str | None):
#    2724     """
#    2725     Rename the left and right indices.
#    2726
#    (...)   2737     x : renamed column name
#    2738     """
#
# ValueError: columns overlap but no suffix specified: Index(['B'], dtype='object')
