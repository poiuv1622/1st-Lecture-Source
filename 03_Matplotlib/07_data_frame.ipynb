# %% [markdown]
# # 10. DataFrame 시각화
# ---
# ### DataFrame과 Matplotlib
# - Pandas DataFrame의 데이터를 Matplotlib로 시각화할 수 있다.
# - DataFrame의 컬럼을 직접 plot() 함수에 전달하여 그래프를 그릴 수 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 한글 폰트 설정
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac 사용자
matplotlib.rcParams['font.size'] = 15 # 폰트 크기 설정
matplotlib.rcParams['axes.unicode_minus'] = False # 마이너스 기호 깨짐 방지

# %% [markdown]
# ## 데이터 준비
# ### customers3.csv 파일 불러오기
# - Pandas로 CSV 파일을 불러온다.

# %%
# 고객 데이터 불러오기
df = pd.read_csv('../02_Pandas/data/customers3.csv', encoding='utf-8')
df.head()
# Out:
#    고객ID  고객명  나이 거주도시        주요관심사  최근1년_방문빈도  평균구매액(만원)  고객만족도(점)  재구매의사(점)
# 0  C001  박태근  35   시흥  Electronics         75         70        78        92
# 1  C002  이영희  30   안양      fashion         85         92        88        85
# 2  C003  박지성  35   울산          NaN         95        110        91        88
# 3  C004  최민아  40   창원      Fashion         92        105        82        96
# 4  C005  정수빈  28   구로      Fashion         82         88        94        79

# %% [markdown]
# ## 단일 컬럼 그래프
# ### DataFrame 컬럼으로 그래프 그리기
# - DataFrame의 특정 컬럼을 X축과 Y축에 전달하여 그래프를 그린다.

# %%
#고객id, 나이 그래프
plt.plot(df['고객ID'],df['나이'],marker='o')

plt.title('고객별 나이')
plt.xlabel('고객ID')
plt.ylabel('나이')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 여러 컬럼 동시 그리기
# ### 여러 데이터를 하나의 그래프에 표시
# - 여러 컬럼의 데이터를 한 그래프에 그려 비교할 수 있다.

# %%
#고객id, 나이 그래프
plt.plot(df['고객ID'],df['고객만족도(점)'], label='고객만족도', marker='o')
plt.plot(df['고객ID'],df['재구매의사(점)'], label='재구매의사', marker='s')

plt.legend(fontsize=12)

plt.xlabel('고객ID')
plt.ylabel('점수')
plt.title('고객별 만족도 & 재구매의사')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 그리드 추가하기
# ### grid() 함수
# - **grid()** 함수를 사용하여 그래프에 그리드를 추가할 수 있다.
# - 그리드는 데이터 값을 더 쉽게 읽을 수 있도록 도와준다.

# %%
#고객id, 나이 그래프
plt.plot(df['고객ID'],df['고객만족도(점)'], label='고객만족도', marker='o')
plt.plot(df['고객ID'],df['재구매의사(점)'], label='재구매의사', marker='s')

plt.legend(fontsize=12, frameon=False)

plt.xlabel('고객ID')
plt.ylabel('점수')
plt.title('고객별 만족도 & 재구매의사')

plt.xticks(rotation=45)

plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ### 그리드 스타일 커스터마이징
# - **axis**: 그리드를 표시할 축 ('x', 'y', 'both')
# - **color**: 그리드 색상
# - **linestyle**: 선 스타일 ('-', '--', '-.', ':')
# - **alpha**: 투명도 (0~1)
# - **linewidth**: 선 두께

# %%
#고객id, 나이 그래프
plt.plot(df['고객ID'],df['고객만족도(점)'], label='고객만족도', marker='o')
plt.plot(df['고객ID'],df['재구매의사(점)'], label='재구매의사', marker='s')

plt.legend(fontsize=12, frameon=False)

plt.xlabel('고객ID')
plt.ylabel('점수')
plt.title('고객별 만족도 & 재구매의사')

plt.xticks(rotation=45)

plt.grid(axis='y', ls='--', color='purple',alpha=0.5)
plt.show()
